# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random data
np.random.seed(1)
x = np.random.rand(100, 1)
y = 2 + 3 * x + np.random.randn(100, 1)

# Plot the data
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
def gradient_descent(X, y, learning_rate, num_iterations):
    # Initialize parameters
    n_features = X.shape[1]
    weights = np.zeros((n_features, 1))
    cost_history = []
    
    # Loop over the specified number of iterations
    for i in range(num_iterations):
        # Calculate the gradient
        y_pred = np.dot(X, weights)
        error = y_pred - y
        gradient = np.dot(X.T, error) / len(y)
        
        # Update weights
        weights -= learning_rate * gradient
        
        # Calculate the cost and add it to the history
        cost = np.sum(np.square(error)) / (2 * len(y))
        cost_history.append(cost)
    
    return weights, cost_history

# Add a bias term to x
X = np.hstack((np.ones((100, 1)), x))

# Run Gradient Descent
learning_rate = 0.1
num_iterations = 100
weights_gd, cost_history_gd = gradient_descent(X, y, learning_rate, num_iterations)

# Plot the data and the line
plt.scatter(x, y)
plt.plot(x, np.dot(X, weights_gd), color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# Plot the cost history
plt.plot(cost_history_gd)
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.show()

# %%
def gradient_descent_with_momentum(X, y, learning_rate, momentum, num_iterations):
    # Initialize parameters
    n_features = X.shape[1]
    weights = np.zeros((n_features, 1))
    velocity = np.zeros((n_features, 1))
    cost_history = []
    
    # Loop over the specified number of iterations
    for i in range(num_iterations):
        # Calculate the gradient
        y_pred = np.dot(X, weights)
        error = y_pred - y
        gradient = np.dot(X.T, error) / len(y)
        
        # Update velocity and weights
        velocity = momentum * velocity - learning_rate * gradient
        weights += velocity
        
        # Calculate the cost and add it to the history
        cost = np.sum(np.square(error)) / (2 * len(y))
        cost_history.append(cost)
    
    return weights, cost_history

# Add a bias term to x
X = np.hstack((np.ones((100, 1)), x))

# Run Gradient Descent with Momentum
learning_rate = 0.1
momentum = 0.9
num_iterations = 100
weights_gdm, cost_history_gdm = gradient_descent_with_momentum(X, y, learning_rate, momentum, num_iterations)

# Plot the data and the line
plt.scatter(x, y)
plt.plot(x, np.dot(X, weights_gdm), color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# Plot the cost history
plt.plot(cost_history_gdm)
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.show()
